# %%
import numpy as np

# %%
a=np.random.randn(5)

# %%
a
# Out:
# array([-0.79991783, -0.30199681, -1.49452335,  0.23955429,  1.08262743])

# %%
a.shape
# Out:
# (5,)

# %% [markdown]
# #### The shape of vector 'a' is (5,) which is called as a rank 1 vector.
# #### It is neither a row vector nor a column vector
# #### hence now a.T == a

# %%
a.T
# Out:
# array([-0.79991783, -0.30199681, -1.49452335,  0.23955429,  1.08262743])

# %%
a=a.reshape(5,1)

# %%
a
# Out:
# array([[-0.79991783],
#        [-0.30199681],
#        [-1.49452335],
#        [ 0.23955429],
#        [ 1.08262743]])

# %%
a.T
# Out:
# array([[-0.79991783, -0.30199681, -1.49452335,  0.23955429,  1.08262743]])

# %%
np.dot(a,a.T)
# Out:
# array([[ 0.63986853,  0.24157263,  1.19549588, -0.19162375, -0.86601298],
#        [ 0.24157263,  0.09120207,  0.45134129, -0.07234463, -0.32695003],
#        [ 1.19549588,  0.45134129,  2.23360005, -0.35801949, -1.61801197],
#        [-0.19162375, -0.07234463, -0.35801949,  0.05738626,  0.25934805],
#        [-0.86601298, -0.32695003, -1.61801197,  0.25934805,  1.17208215]])

# %% [markdown]
# The above dot product gives m*m dimension vector

# %%
x=np.random.randn(32,32,3)

# %%
x
# Out:
# array([[[ 0.76929307,  0.29906428, -0.19502152],
#         [-0.87572284,  1.33017254, -1.10574076],
#         [ 0.84338245,  1.10616379, -0.33455515],
#         ...,
#         [-0.15768908, -0.30167192,  1.13941838],
#         [ 0.24380872,  2.81630421,  0.04441587],
#         [ 0.45651866, -0.36100664, -0.85230287]],
#
#        [[ 1.16246359,  0.51450009, -0.93738954],
#         [-0.09894864,  2.43174974, -0.62420088],
#         [-1.12811542, -1.72444445, -1.03127405],
#         ...,
#         [ 1.56868742, -0.7530398 ,  0.61649804],
#         [-0.68118813, -1.39205064,  0.07723466],
#         [-0.11241742,  0.19860641,  0.53499744]],
#
#        [[ 0.50860624, -1.32908352, -0.03180747],
#         [ 0.51824727,  0.60925385,  0.54329767],
#         [ 0.24394424, -0.31759752, -0.4341191 ],
#         ...,
#         [ 0.51773184,  0.01121728,  0.6695587 ],
#         [-1.11709457,  1.19226776,  1.04887671],
#         [-0.0922941 ,  0.53185109, -0.14796965]],
#
#        ...,
#
# ...

# %%
x.reshape(3,32,32)
# Out:
# array([[[ 0.76929307,  0.29906428, -0.19502152, ..., -1.21224516,
#          -1.34075007, -0.53007077],
#         [ 0.77045306,  1.12649832, -0.25935507, ...,  1.57820298,
#          -1.20434917,  0.14399466],
#         [ 0.30729229, -0.13293016,  0.51699901, ...,  0.45651866,
#          -0.36100664, -0.85230287],
#         ...,
#         [-0.16364285, -0.89423251,  1.27001647, ...,  0.48650343,
#           0.91677435,  0.09817097],
#         [ 0.98232796,  1.73748888, -0.82200395, ..., -1.15498658,
#          -0.87617279,  0.04862507],
#         [ 0.58022   , -2.78931783, -0.05196837, ...,  1.07796272,
#           0.20050131,  0.14870523]],
#
#        [[-1.22718123, -0.96362804, -0.39093679, ...,  0.49893477,
#          -1.5348587 , -1.8438875 ],
#         [-0.72039583, -2.06284135,  1.07663372, ...,  0.50411433,
#           0.35883644, -0.95766659],
#         [ 1.30708021, -0.71057721,  0.26462551, ...,  0.87963747,
#          -0.19879727,  0.31461374],
#         ...,
# ...
